# %% [markdown]
# <a href="https://colab.research.google.com/github/mahitha010/Advanced-Gen-AI-internship-Innomatics/blob/main/Logic_Building_Task4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def validate_recharge():
    valid_plans = [199, 299, 399, 599]
    while True:
        amount = int(input("Enter recharge amount:"))

        if amount < 50:
            print("Amount must be at least ₹50. Try again.")

        elif amount not in valid_plans:
            print("Invalid plan selected. Available plans:", valid_plans)

        else:
            print("Recharge successful!")
            break

validate_recharge()
# Out:
# Enter recharge amount:299
# Recharge successful!

# %%
def check_inventory(products):
    for item, stock in products.items():
        if stock < 15:
            print(item, "- Reorder Alert")
        else:
            print(item, "- Stock OK")

products = {
    "Rice": 20,"Sugar": 10,"Oil": 5,"Salt": 25
}

check_inventory(products)
# Out:
# Rice - Stock OK
# Sugar - Reorder Alert
# Oil - Reorder Alert
# Salt - Stock OK

# %%
def check_result(marks):
    total = 0
    for mark in marks:
        total += mark
    average = total / len(marks)
    print("Average:", average)

    if average >= 50:
        return "Pass"
    else:
        return "Fail"
marks = [60, 45, 70, 55]
result = check_result(marks)
print("Result:", result)
# Out:
# Average: 57.5
# Result: Pass

# %%
def calculate_fare(distance, peak):
    fare = 50 + (12 * distance)

    if peak == "yes":
        fare = fare + (fare * 0.25)

    return fare

while True:
    km = float(input("Enter distance in km: "))
    peak_hour = input("Is it peak hour? (yes/no): ")
    total_fare = calculate_fare(km, peak_hour)
    print("Total Fare: ₹", total_fare)
    retry = input("Do you want to calculate again? (yes/no): ")
    if retry.lower() != "yes":
        break
# Out:
# Enter distance in km: 67
# Is it peak hour? (yes/no): yes
# Total Fare: ₹ 1067.5
# Do you want to calculate again? (yes/no): no

# %%
def check_attendance(attendance):
    present_count = 0

    for day in attendance:
        if day == "P":
            present_count += 1

    percentage = (present_count / len(attendance)) * 100
    print("Attendance Percentage:", percentage)

    if percentage >= 75:
        return "Eligible"
    else:
        return "Not Eligible"

attendance_list = ["P", "P", "A", "P", "P", "A", "P"]
status = check_attendance(attendance_list)
print("Status:", status)
# Out:
# Attendance Percentage: 71.42857142857143
# Status: Not Eligible

# %%
def check_password(password):
    has_digit = False
    has_special = False
    special_chars = "@#$"

    if len(password) < 8:
        return "Weak Password (Minimum 8 characters required)"

    for char in password:
        if char.isdigit():
            has_digit = True
        if char in special_chars:
            has_special = True

    if has_digit and has_special:
        return "Strong Password"
    else:
        return "Weak Password"

pwd = input("Enter password: ")
print(check_password(pwd))
# Out:
# Enter password: Abcd@#123!
# Strong Password
